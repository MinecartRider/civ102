# %%
import sys, os
sys.path.append(os.path.abspath("../.."))
from helpers import cross_section as cs
import numpy as np
from helpers import properties as pr
from helpers import flexural_stress as fs

# %%
def shear_calculation(V, Q, I, b):
    return V * Q / I / b

# %%
V = -323
I = 1070000

# %%
print(shear_calculation(V, 10971, I, 1.298))
fs.flexural_comp(I, 160-35.2, 160)
fs.flexural_tens(I, 160-35.2)
# Out:
# -2.5514688305516757
# Flexural Compressive Stress: 2.826198130841122
# FOS(Flexural Compression) = 2.122993407477169
# Flexural Tensile Stress: 10.020157009345795
# FOS(Flexural Tension) = 2.9939650618267777

# %%
print(pr.local_buckling(2.54, 65,4))
print(pr.local_buckling(2.54, 16.865,0.425))
print(pr.local_buckling(1.30, 33.35,6))
print(pr.shear_buckling(1.30, 160.8, 125))
# Out:
# 20.93186711179096
# 33.03626414239449
# 31.243058077110273
# 2.9732249590098987
